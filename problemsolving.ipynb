# %% [markdown]
# ![لقطة شاشة 2023-10-13 032726.png](data:image/png;base64,...)

# %%
if __name__ == '__main__':
    n = int(input())

for i in range(0,n):
    print(i*i)
# Out:
# 2
# 0
# 1

# %% [markdown]
# ![لقطة شاشة 2023-10-13 033529.png](data:image/png;base64,...)

# %%
import math
import os
import random
import re
import sys



if __name__ == '__main__':
    n = int(input().strip())
if (n%2!=0) or (n>=6 and n<=20):
    print("Weird")
else:
    print("Not Weird")
# Out:
# 5
# Weird

# %% [markdown]
# ![لقطة شاشة 2023-10-13 033910.png](data:image/png;base64,...)

# %%
if __name__ == '__main__':
    n = int(input())
    integer_list = tuple(map(int, input().split()))
    print(hash(integer_list))
# Out:
# 1
# 2
# 6909455589863252355
