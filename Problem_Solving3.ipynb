# %% [markdown]
# ![لقطة شاشة 2023-10-24 204910.png](data:image/png;base64,...)

# %%
def split_and_join(line):
    # write your code here
    return '-'.join(line.split(" "))

if __name__ == '__main__':
    line = input()
    result = split_and_join(line)
    print(result)
# Out:
# this iss a strimg
# this-iss-a-strimg

# %% [markdown]
# ![لقطة شاشة 2023-10-24 205325.png](data:image/png;base64,...)

# %%
import textwrap

def ras(string, max_width):
    return textwrap.fill(string,max_width)

if __name__ == '__main__':
    string, max_width = input(), int(input())
    result = ras(string, max_width)
    print(result)
# Out:
# ABCDEFGHIJKLIMNOQRSSTUVWXYZ
# 4
# ABCD
# EFGH
# IJKL
# IMNO
# QRSS
# TUVW
# XYZ

# %% [markdown]
# ![لقطة شاشة 2023-10-24 210919.png](data:image/png;base64,...)

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT
n, m = input().split()
ss= input().split()
A = set(input().split())
B = set(input().split())
print(sum([(i  in A) -(i in B)for i in ss]))
# Out:
# 3 2
# 1 5 3
# 3 1
# 5 7
# 1

# %% [markdown]
# ![لقطة شاشة 2023-10-24 211256.png](data:image/png;base64,...)

# %%
def is_leap(n):
    if n % 400 == 0:
        return True
    if n % 100 == 0:
        return False
    if n % 4 == 0:
        return True
    return False


    # Write your logic here

    return leap

year = int(input())
print(is_leap(year))
# Out:
# 1990
# False

# %% [markdown]
# ![لقطة شاشة 2023-10-24 215150.png](data:image/png;base64,...)

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT

for _ in range(int(input())):
    x, a, z, b = input(), set(input().split()),input(),set(input().split())
    print(a.issubset(b))
# Out:
# 3
# 5
# 1 2 3 4 5 6
# 9
# 9 8 5 6 3 2 1 4 7
# True
# 1
# 2
# 5
# 3 6 5 4 1
# False
# 7
# 1
# 1 2 3 4 5 6 8 9
# 3
# False

# %% [markdown]
# ![لقطة شاشة 2023-10-24 223031.png](data:image/png;base64,...)

# %%
n, m = map(int,input().split())
pattern = [('.|.'*(2*i + 1)).center(m, '-') for i in range(n//2)]
print('\n'.join(pattern + ['WELCOME'.center(m, '-')] + pattern[::-1]))
# Out:
# 9 27
# ------------.|.------------
# ---------.|..|..|.---------
# ------.|..|..|..|..|.------
# ---.|..|..|..|..|..|..|.---
# ----------WELCOME----------
# ---.|..|..|..|..|..|..|.---
# ------.|..|..|..|..|.------
# ---------.|..|..|.---------
# ------------.|.------------

# %% [markdown]
# ![لقطة شاشة 2023-10-24 224414.png](data:image/png;base64,...)

# %%
if __name__ == '__main__':
    n = int(input())
    arr = map(int, input().split())
    arr1 = set(arr)
    arr1 = list(arr1)
    rr = max(arr1)
    arr1.remove(rr)
    print(max(arr1))
# Out:
# 5
# 2 3 6 6 5
# 5

# %% [markdown]
# ![لقطة شاشة 2023-10-24 224814.png](data:image/png;base64,...)

# %%
if __name__ == '__main__':
    n = int(input())
    student_marks = {}
    for _ in range(n):
        name, *line = input().split()
        scores = list(map(float, line))
        student_marks[name] = scores
    query_name = input()

    rrr = 0
    for i in student_marks[query_name]:
        rrr=rrr+i
    print("{0:.2f}".format(rrr/3))
# Out:
# 3
# Krishna 67 68 69
# arjun 70 98 63
# malika 52 56 60
# malika
# 56.00

# %% [markdown]
# ![لقطة شاشة 2023-10-24 225245.png](data:image/png;base64,...)

# %%
def merge_the_tools(string, k):
    # your code goes here
    ccc = 0
    s =''
    for i in string:
        if i not in s:
            s=s+i
        ccc+=1
        if(ccc==k):
            print(s)
            ccc=0
            s=''

if __name__ == '__main__':
    string, k = input(), int(input())
    merge_the_tools(string, k)
# Out:
# AB
# 3

# %% [markdown]
# ![لقطة شاشة 2023-10-24 225719.png](data:image/png;base64,...)

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT

from collections import Counter
nn = int(input())
ll = list()
for _ in range(nn):
    ll.append(input())
xx = Counter(ll)
print(len(xx))
print(*xx.values())
# Out:
# 4
# bcdef
# abcdefg
# vcde
# bcdef
# 3
# 2 1 1

# %% [markdown]
# ![لقطة شاشة 2023-10-24 230238.png](data:image/png;base64,...)

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT

from itertools import *

nn = input()

for i,j in groupby(nn):
    print(tuple([len(list(j)),int(i)]),end=" ")
# Out:
# 1222311
# (1, 1) (3, 2) (1, 3) (2, 1)

# %% [markdown]
# ![لقطة شاشة 2023-10-25 011934.png](data:image/png;base64,...)

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT
from itertools import combinations

nn = input()
ss = list(input().split(' '))

k = int(input())
cc = 0
for i in combinations(ss,k):
    if 'a' in i:
        cc=cc+1
print(cc/len(list(combinations(ss,k))))
# Out:
# 4
# a a c d
# 2
# 0.8333333333333334
